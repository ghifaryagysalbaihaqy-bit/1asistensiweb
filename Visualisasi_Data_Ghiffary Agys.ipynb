# %% [markdown]
# <a href="https://colab.research.google.com/github/ghifaryagysalbaihaqy-bit/1asistensiweb/blob/main/Visualisasi_Data_Ghiffary%20Agys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = ["Fatwa", "Ichwal", "Zaki", "Aan", "Rafli"]
nilai = [85, 72, 90, 78, 95]

# %%
import matplotlib.pyplot as plt

# Buat ulang kode cell untuk visualisasi seperti di bawah ini:

# %%
hari = ["Sen", "Sel", "Rab", "Kam", "Jum", "Sab", "Min"]
penjualan = [12, 18, 15, 20, 25, 30, 28]

# %%
# Buat ulang kode cell untuk visualisasi seperti di bawah ini:

# %%
jam_belajar = [1, 2, 3, 4, 5, 6, 7]
nilai = [55, 60, 65, 72, 80, 90, 95]

# %%
# Buat ulang kode cell untuk visualisasi seperti di bawah ini:

# %%
label = ["Python", "Java", "C++", "PHP"]
jumlah = [40, 30, 20, 10]

# %%
# Buat ulang kode cell untuk visualisasi seperti di bawah ini:

# %%
nilai = [65,70,72,75,80,82,84,85,85,87,88,90,91,92,95]

# %%
# Buat ulang kode cell untuk visualisasi seperti di bawah ini:
